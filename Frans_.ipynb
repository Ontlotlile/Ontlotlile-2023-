# %% [markdown]
# <a href="https://colab.research.google.com/github/Ontlotlile/Ontlotlile-2023-/blob/main/Frans_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
   import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
#import pandas_datareader as web
from scipy.stats import skew, kurtosis
import seaborn as sns
from scipy.stats import norm  # You can choose a different distribution if needed
import matplotlib.pyplot as plt
from collections import deque
import datetime
import scipy.stats as stats
import statistics as st
import matplotlib.pyplot as plt

from scipy.stats import kstest

# %%
def download_portfolio_adj_close(tickers, start_date, end_date):
    data = yf.download(tickers, start=start_date, end=end_date)['Adj Close']
    return data

def export_to_csv(data, filename):
    data.to_csv(filename)

tickers1 = ['SI=F']
tickers2 = ['CL=F']
tickers3=  ['GC=F']
start_date = '2018-08-16'
end_date = '2023-08-15'

SA_portfolio_prices = download_portfolio_adj_close(tickers1, start_date, end_date)

US_portfolio_prices = download_portfolio_adj_close(tickers2, start_date, end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
import yfinance as yf
import matplotlib.pyplot as plt

def download_portfolio_adj_close(tickers, start_date, end_date):
    data = yf.download(tickers, start=start_date, end=end_date)['Adj Close']
    return data

def export_to_csv(data, filename):
    data.to_csv(filename)

tickers1 = ['SI=F']
tickers2 = ['CL=F']
tickers3 = ['GC=F']
start_date = '2018-08-16'
end_date = '2023-08-15'

silver_prices = download_portfolio_adj_close(tickers1, start_date, end_date)
oil_prices = download_portfolio_adj_close(tickers2, start_date, end_date)
gold_prices = download_portfolio_adj_close(tickers3, start_date, end_date)

# Plot the adjusted closing prices of the commodities
plt.figure(figsize=(12, 6))
plt.plot(silver_prices, label='Silver Prices')
plt.plot(oil_prices, label='Oil Prices')
plt.plot(gold_prices, label='Gold Prices')

plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Commodity Prices Over Time')
plt.legend()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
import yfinance as yf
import matplotlib.pyplot as plt

def download_portfolio_adj_close(tickers, start_date, end_date):
    data = yf.download(tickers, start=start_date, end=end_date)['Adj Close']
    return data

def export_to_csv(data, filename):
    data.to_csv(filename)

tickers1 = ['SI=F']frans contains the Excel spreadsheets that display the mathematical calculations used to create the
tickers2 = ['CL=F']
tickers3 = ['GC=F']
start_date = '2018-08-16'
end_date = '2023-08-15'

silver_prices = download_portfolio_adj_close(tickers1, start_date, end_date)
oil_prices = download_portfolio_adj_close(tickers2, start_date, end_date)
gold_prices = download_portfolio_adj_close(tickers3, start_date, end_date)

# Plot the adjusted closing prices of the commodities on separate plots
plt.figure(figsize=(6, 10))

plt.subplot(3, 1, 1)
plt.plot(silver_prices, label='Silver Prices')
plt.ylabel('Price')
plt.title('Silver Prices Over Time')

plt.subplot(3, 1, 2)
plt.plot(oil_prices, label='Oil Prices')
plt.ylabel('Price')
plt.title('Oil Prices Over Time')

plt.subplot(3, 1, 3)
plt.plot(gold_prices, label='Gold Prices')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Prices Over Time')

plt.tight_layout()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
import yfinance as yf
import matplotlib.pyplot as plt

def download_portfolio_adj_close(tickers, start_date, end_date):
    data = yf.download(tickers, start=start_date, end=end_date)['Adj Close']
    return data

def export_to_csv(data, filename):
    data.to_csv(filename)

tickers1 = [ '^IXIC' ]  # NASDAQ
tickers2 = [ '^GSPC' ]  # S&P 500
tickers3 = [ '^DJI' ]   # Dow Jones
start_date = '2018-08-16'
end_date = '2023-08-15'

nasdaq_prices = download_portfolio_adj_close(tickers1, start_date, end_date)
sp500_prices = download_portfolio_adj_close(tickers2, start_date, end_date)
dowjones_prices = download_portfolio_adj_close(tickers3, start_date, end_date)

# Plot the adjusted closing prices of the indices on separate plots with red lines
plt.figure(figsize=(6, 10))

plt.subplot(3, 1, 1)
plt.plot(nasdaq_prices, label='NASDAQ (^IXIC)', color='red')
plt.ylabel('Price')
plt.title('NASDAQ  Prices Over Time')

plt.subplot(3, 1, 2)
plt.plot(sp500_prices, label='S&P 500 (^GSPC)', color='red')
plt.ylabel('Price')
plt.title('S&P 500  Prices Over Time')

plt.subplot(3, 1, 3)
plt.plot(dowjones_prices, label='Dow Jones (^DJI)', color='red')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Dow Jones  Prices Over Time')

plt.tight_layout()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
import yfinance as yf
import matplotlib.pyplot as plt

def download_portfolio_adj_close(tickers, start_date, end_date):
    data = yf.download(tickers, start=start_date, end=end_date)['Adj Close']
    return data

def export_to_csv(data, filename):
    data.to_csv(filename)

tickers1 = ['FBND']  # NASDAQ
tickers2 = ['BHYAX']  # S&P 500
tickers3 = ['BYMMX']   # Dow Jones
start_date = '2018-08-16'
end_date = '2023-08-15'

nasdaq_prices = download_portfolio_adj_close(tickers1, start_date, end_date)
sp500_prices = download_portfolio_adj_close(tickers2, start_date, end_date)
dowjones_prices = download_portfolio_adj_close(tickers3, start_date, end_date)

# Plot the adjusted closing prices of the indices on separate plots with yellow lines
plt.figure(figsize=(6, 10))

plt.subplot(3, 1, 1)
plt.plot(nasdaq_prices, label=' FBND ' , color='brown')
plt.ylabel('Price')
plt.title('Fidelity Prices Over Time')

plt.subplot(3, 1, 2)
plt.plot(sp500_prices, label=' BHYAX ', color='brown')
plt.ylabel('Price')
plt.title('BlackRock Prices Over Time')

plt.subplot(3, 1, 3)
plt.plot(dowjones_prices, label=' BYMMX ', color='brown')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('BNY Mellon Prices Over Time')

plt.tight_layout()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
